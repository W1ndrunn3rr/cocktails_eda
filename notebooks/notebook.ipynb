# %%
import pandas as pd

data = pd.read_csv("data.csv")

# %%
data = data.drop(["Unnamed: 0"],axis=1)

# %%
data.tags.value_counts()
# Out:
# tags
# []                                                                                                             99
# ['IBA', 'ContemporaryClassic']                                                                                 10
# ['IBA', 'Classic']                                                                                              3
# ['Strong', 'Asia', 'StrongFlavor', 'Brunch', 'Vegetarian', 'Sour']                                              1
# ['IBA', 'ContemporaryClassic', 'Alcoholic', 'USA', 'Asia', 'Vegan', 'Citrus', 'Brunch', 'Hangover', 'Mild']     1
# ['IBA', 'Classic', 'Alcoholic', 'ContemporaryClassic']                                                          1
# ['IBA', 'Classic', 'Christmas', 'Alcoholic']                                                                    1
# ['IBA', 'Classic', 'Beach']                                                                                     1
# ['IBA', 'Classic', 'Alcoholic', 'Expensive', 'Savory']                                                          1
# ['IBA', 'Classic', 'Alcoholic']                                                                                 1
# ['DinnerParty']                                                                                                 1
# ['Summer']                                                                                                      1
# ['Beach', 'Chilli']                                                                                             1
# ['IBA', 'Classic', 'Dairy']                                                                                     1
# ['Nutty', 'Dairy']                                                                                              1
# ['Alcoholic']                                                                                                   1
# ['Cold']                                                                                                        1
# ['Fruity']                                                                                                      1
# ['Breakfast', 'Brunch', 'Hangover']                                                                             1
# ['ContemporaryClassic', 'IBA']                                                                                  1
# ['Citrus', 'StrongFlavor']                                                                                      1
# ['Sour']                                                                                                        1
# ['Beach']                                                                                                       1
# ['IBA']                                                                                                         1
# ['IBA', 'NewEra']                                                                                               1
# Name: count, dtype: int64

# %%
data.isnull().values.any()
# Out:
# np.False_

# %%
data.hist()
# Out:
# array([[<Axes: title={'center': 'instruction_length'}>,
#         <Axes: title={'center': 'ingredients_count'}>],
#        [<Axes: title={'center': 'mean_alcohol_percentage'}>,
#         <Axes: title={'center': 'complexity_score'}>]], dtype=object)
